# %%
# Google Drive Source Data
# https://docs.google.com/spreadsheets/d/130aaV6F5jIBbz5J5FgtiwGPawKgtg4bt/edit?usp=sharing&ouid=102514651699712419557&rtpof=true&sd=true

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://docs.google.com/spreadsheets/d/130aaV6F5jIBbz5J5FgtiwGPawKgtg4bt/edit?usp=sharing&ouid=102514651699712419557&rtpof=true&sd=true'
file_id = url.split('/')[-2]
read_url='https://drive.google.com/uc?id=' + file_id

# %%
# read the data
pd.read_excel(read_url)
# Out:
#             Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 0     CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1     CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2     CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3     US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4     US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
# ...              ...         ...          ...              ...       ...
# 9989  CA-2017-110422    TB-21400        33180  FUR-FU-10001889   25.2480
# 9990  CA-2020-121258    DB-13060        92627  FUR-FU-10000747   91.9600
# 9991  CA-2020-121258    DB-13060        92627  TEC-PH-10003645  258.5760
# 9992  CA-2020-121258    DB-13060        92627  OFF-PA-10004041   29.6000
# 9993  CA-2020-119914    CC-12220        92683  OFF-AP-10002684  243.1600
#
#       Quantity  Discount    Profit         Category Sub-Category  \
# ...

# %%
df = pd.read_excel(read_url)
df
# Out:
#             Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 0     CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1     CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2     CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3     US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4     US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
# ...              ...         ...          ...              ...       ...
# 9989  CA-2017-110422    TB-21400        33180  FUR-FU-10001889   25.2480
# 9990  CA-2020-121258    DB-13060        92627  FUR-FU-10000747   91.9600
# 9991  CA-2020-121258    DB-13060        92627  TEC-PH-10003645  258.5760
# 9992  CA-2020-121258    DB-13060        92627  OFF-PA-10004041   29.6000
# 9993  CA-2020-119914    CC-12220        92683  OFF-AP-10002684  243.1600
#
#       Quantity  Discount    Profit         Category Sub-Category  \
# ...

# %%
# display the first 5 rows

df. head()
# Out:
#          Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 0  CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1  CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2  CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3  US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4  US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
#
#    Quantity  Discount    Profit         Category Sub-Category  \
# 0         2      0.00   41.9136        Furniture    Bookcases
# 1         3      0.00  219.5820        Furniture       Chairs
# 2         2      0.00    6.8714  Office Supplies       Labels
# 3         5      0.45 -383.0310        Furniture       Tables
# 4         2      0.20    2.5164  Office Supplies      Storage
#
#                                         Product_Name Order_Date  Ship_Date  \
# 0                  Bush Somerset Collection Bookcase 2019-11-08 2019-11-11
# ...

# %% [markdown]
# # **MEMBUAT DATA SENDIRI**

# %%
data_siswa = pd.DataFrame(

)

# %% [markdown]
# **Dataframe in List**

# %%
data_siswa = pd.DataFrame(
    [
        ['Ridho', 173, 73, "M"],
        ['Rudy', 178, 75, "M"],
        ['Cindy', 170, 54, "F"]
    ]
)
data_siswa
# Out:
#        0    1   2  3
# 0  Ridho  173  73  M
# 1   Rudy  178  75  M
# 2  Cindy  170  54  F

# %%
data_siswa = pd.DataFrame(
    [
        ['Ridho', 173, 73, "M"],
        ['Rudy', 178, 75, "M"],
        ['Cindy', 170, 54, "F"]
    ]
)
data_siswa
# Out:
#        0    1   2  3
# 0  Ridho  173  73  M
# 1   Rudy  178  75  M
# 2  Cindy  170  54  F

# %%
data_siswa = pd.DataFrame(
    [
        ['Ridho', 173, 73, "M"],
        ['Rudy', 178, 75, "M"],
        ['Cindy', 170, 54, "F"]
    ], columns = ['Nama', 'Tinggi', 'Berat', 'Jenis Kelamin']
)
data_siswa
# Out:
#     Nama  Tinggi  Berat Jenis Kelamin
# 0  Ridho     173     73             M
# 1   Rudy     178     75             M
# 2  Cindy     170     54             F

# %%
data_siswa = pd.DataFrame(
    [
        ['Ridho', 173, 73, "M"],
        ['Rudy', 178, 75, "M"],
        ['Cindy', 170, 54, "F"]
    ], columns = ['Nama', 'Tinggi', 'Berat', 'Jenis Kelamin']
)
data_siswa
# Out:
#     Nama  Tinggi  Berat Jenis Kelamin
# 0  Ridho     173     73             M
# 1   Rudy     178     75             M
# 2  Cindy     170     54             F

# %%
data_siswa = pd.DataFrame(
    [
        ['Ridho', 173, 73, "M"],
        ['Rudy', 178, 75, "M"],
        ['Cindy', 170, 54, "F"]
    ], columns = ['Nama', 'Tinggi', 'Berat', 'Jenis Kelamin']
)
data_siswa
# Out:
#     Nama  Tinggi  Berat Jenis Kelamin
# 0  Ridho     173     73             M
# 1   Rudy     178     75             M
# 2  Cindy     170     54             F
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# data_siswa['Tinggi'].plot(kind='hist', bins=20, title='Tinggi')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# data_siswa['Berat'].plot(kind='hist', bins=20, title='Berat')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# data_siswa.groupby('Nama').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# ...

# %%
# !pip install openpyxl

# %%
df.to_excel('data_output.xlsx', index=False)

# %%
files.download('data_output.xlsx')
